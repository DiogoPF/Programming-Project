# %% [markdown]
# ### EuCT Data Cleaning:

# %% [markdown]
# #### Library and Data Import:

# %%
import os
import pandas as pd

# %%
path = os.getcwd()

# %%
df = pd.read_csv(r'C:\Users\ggrkn\OneDrive - NOVAIMS\PostGrad\PDS\_Final Project\EuCTRegister.csv', low_memory=False)

# %% [markdown]
# #### Column Selection and Aggregation

# %%
df.shape
# Out:
# (114333, 181)

# %% [markdown]
# The original dataset has 114333 rows and 181 columns so we need to clean it before any analysis.
#
# By their names, we selected a set of 26 possible columns that might interest us

# %%
column_list=['EudraCT Number:','Country','Member State Concerned',
             'Date on which this record was first entered in the EudraCT database:','Date of the global end of the trial',
             'Trial Status:','Therapeutic area','Diagnosis','Prophylaxis','Therapy','Safety','Efficacy',
             'Main objective of the trial','Human pharmacology (Phase I)','Therapeutic exploratory (Phase II)',
             'Therapeutic confirmatory (Phase III)','Therapeutic use (Phase IV)','In Utero','Newborns (0-27 days)',
             'Infants and toddlers (28 days-23 months)','Children (2-11years)','Adolescents (12-17 years)',
             'Adults (18-64 years)','Elderly (>=65 years)','Female','Male', 'Medical condition(s) being investigated', 'Medical condition in easily understood language']

# %%
len(column_list)
# Out:
# 28

# %%
df = df.loc[:,column_list]

# %% [markdown]
# As we can see by the table below there are a lot of columns that are 'dummy' columns that can probably be aggregated to simplify the analysis.

# %%
df.describe().transpose()
# Out:
#                                                      count unique  \
# EudraCT Number:                                     114290  43464
# Country                                              77738     88
# Member State Concerned                              112737     31
# Date on which this record was first entered in ...  114290   4993
# Date of the global end of the trial                  63363   5511
# Trial Status:                                       111285     10
# Therapeutic area                                     78199     55
# Diagnosis                                           114290      3
# Prophylaxis                                         114290      3
# Therapy                                             114290      3
# Safety                                              114290      3
# Efficacy                                            114290      3
# Main objective of the trial                         113518  63401
# Human pharmacology (Phase I)                        114290      3
# Therapeutic exploratory (Phase II)                  114290      3
# Therapeutic confirmatory (Phase III)                114290      3
# Therapeutic use (Phase IV)                          114290      3
# In Utero                                            114290      3
# Newborns (0-27 days)                                114290      3
# Infants and toddlers (28 days-23 months)            114290      3
# Children (2-11years)                                114290      3
# Adolescents (12-17 years)                           114290      3
# Adults (18-64 years)                                114290      3
# Elderly (>=65 years)                                114290      3
# Female                                              114290      3
# Male                                                114290      3
# Medical condition(s) being investigated             113879  47691
# Medical condition in easily understood language      77422  31165
#
#                                                                                                   top  \
# EudraCT Number:                                                                        2017-004295-55
# Country                                                                                 United States
# Member State Concerned                                                                  Spain - AEMPS
# Date on which this record was first entered in ...                                         2021-06-17
# Date of the global end of the trial                                                        2012-12-20
# Trial Status:                                                                               Completed
# Therapeutic area                                                          Diseases [C] - Cancer [C04]
# Diagnosis                                                                                          No
# Prophylaxis                                                                                        No
# Therapy                                                                                           Yes
# Safety                                                                                            Yes
# Efficacy                                                                                          Yes
# Main objective of the trial                         Demonstrate that ofatumumab 20 mg sc once ever...
# Human pharmacology (Phase I)                                                                       No
# Therapeutic exploratory (Phase II)                                                                 No
# Therapeutic confirmatory (Phase III)                                                              Yes
# Therapeutic use (Phase IV)                                                                         No
# In Utero                                                                                           No
# Newborns (0-27 days)                                                                               No
# Infants and toddlers (28 days-23 months)                                                           No
# Children (2-11years)                                                                               No
# Adolescents (12-17 years)                                                                          No
# Adults (18-64 years)                                                                              Yes
# Elderly (>=65 years)                                                                              Yes
# Female                                                                                            Yes
# Male                                                                                              Yes
# Medical condition(s) being investigated                                          Rheumatoid Arthritis
# Medical condition in easily understood language                                                Asthma
#
#                                                       freq
# EudraCT Number:                                         24
# Country                                              17694
# Member State Concerned                               11095
# Date on which this record was first entered in ...     327
# Date of the global end of the trial                     60
# Trial Status:                                        66850
# Therapeutic area                                     21952
# Diagnosis                                           108189
# Prophylaxis                                         103340
# Therapy                                              63972
# Safety                                              103257
# Efficacy                                            101944
# Main objective of the trial                             27
# Human pharmacology (Phase I)                        106469
# Therapeutic exploratory (Phase II)                   70268
# Therapeutic confirmatory (Phase III)                 60094
# Therapeutic use (Phase IV)                           98019
# In Utero                                             93835
# Newborns (0-27 days)                                 92170
# Infants and toddlers (28 days-23 months)             88099
# Children (2-11years)                                 82205
# Adolescents (12-17 years)                            78255
# Adults (18-64 years)                                102709
# Elderly (>=65 years)                                 86288
# Female                                              109773
# Male                                                107306
# Medical condition(s) being investigated                694
# Medical condition in easily understood language        607

# %% [markdown]
# We started by defining the agregation funcionts based on the subgroups of columns.

# %%
def aggregate_columns_phase(row):
    yes_columns = [col for col in row.index if col in ['Human pharmacology (Phase I)','Therapeutic exploratory (Phase II)',
             'Therapeutic confirmatory (Phase III)','Therapeutic use (Phase IV)'] 
                   and row[col] == 'Yes']
    return ', '.join(yes_columns) if yes_columns else ''

# %%
def aggregate_columns_age(row):
    yes_columns = [col for col in row.index if col in ['In Utero','Newborns (0-27 days)',
             'Infants and toddlers (28 days-23 months)','Children (2-11years)','Adolescents (12-17 years)',
             'Adults (18-64 years)','Elderly (>=65 years)'] 
                   and row[col] == 'Yes']
    return ', '.join(yes_columns) if yes_columns else ''

# %%
def aggregate_columns_scope(row):
    yes_columns = [col for col in row.index if col in ['Diagnosis', 'Prophylaxis', 'Therapy', 'Safety', 'Efficacy'] 
                   and row[col] == 'Yes']
    return ', '.join(yes_columns) if yes_columns else ''

# %%
def aggregate_columns_gender(row):
    yes_columns = [col for col in row.index if col in ['Female','Male'] 
                   and row[col] == 'Yes']
    return ', '.join(yes_columns) if yes_columns else ''

# %% [markdown]
# And then apply the aggregation function to the dataset to group the column values:

# %%
df['Scope of the Trial'] = df.apply(aggregate_columns_scope, axis=1)
df['Trial Phase'] = df.apply(aggregate_columns_phase, axis=1)
df['Age Group'] = df.apply(aggregate_columns_age, axis=1)
df['Gender'] = df.apply(aggregate_columns_gender, axis=1)

# %% [markdown]
# Finally, we deleted the unecessary columns. Our new dataset has now 114333rows and 12 columns.

# %%
df.drop(['Diagnosis', 'Prophylaxis', 'Therapy', 'Safety', 'Efficacy',
        'Human pharmacology (Phase I)','Therapeutic exploratory (Phase II)',
         'Therapeutic confirmatory (Phase III)','Therapeutic use (Phase IV)',
         'In Utero','Newborns (0-27 days)', 'Infants and toddlers (28 days-23 months)','Children (2-11years)',
         'Adolescents (12-17 years)','Adults (18-64 years)','Elderly (>=65 years)','Female','Male'],
        axis=1, inplace = True)

# %%
df.shape
# Out:
# (114333, 14)

# %% [markdown]
# #### Column Rename and Data Split

# %% [markdown]
# Having reduced the number of columns it was necessary to rename some of the columns to a more intuitive name.
#
# Additionally, as we are focusing on depression and neurological diseases we must filter and split the dataset.

# %%
df = df.rename(columns={'Date on which this record was first entered in the EudraCT database:':'Start Date',
                         'Member State Concerned':'Member State',
                         'Date of the global end of the trial':'End Date',
                       'Scope of the Trial':'Trial Scope'})

# %%
depression_trials = df[(df['Therapeutic area'] == 'Psychiatry and Psychology [F] - Mental Disorders [F03]') |
                    (df['Therapeutic area'] == 'Psychiatry and Psychology [F] - Behaviours [F01]') |
                    (df['Therapeutic area'] == 'Psychiatry and Psychology [F] - Behavioral Disciplines and Activities [F04]') |
                    (df['Therapeutic area'] == 'Psychiatry and Psychology [F] - Psychological processes [F02]')]

# %%
#neural_trials = df[(df['Therapeutic area'] == 'Diseases [C] - Nervous System Diseases [C10]')]

# %%
neurology_trials = df[(df['Therapeutic area'] == 'Diseases [C] - Nervous System Diseases [C10]') |
                    (df['Therapeutic area'] == 'Diseases [C] - Cardiovascular Diseases [C14]')]

# %% [markdown]
# ### Conclusions and Export

# %% [markdown]
# The following tables summarize the main information regarding both datasets:

# %%
depression_trials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1785 entries, 17 to 114272
# Data columns (total 14 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   EudraCT Number:                                  1785 non-null   object
#  1   Country                                          1768 non-null   object
#  2   Member State                                     1757 non-null   object
#  3   Start Date                                       1785 non-null   object
#  4   End Date                                         1042 non-null   object
#  5   Trial Status:                                    1707 non-null   object
#  6   Therapeutic area                                 1785 non-null   object
#  7   Main objective of the trial                      1783 non-null   object
#  8   Medical condition(s) being investigated          1780 non-null   object
#  9   Medical condition in easily understood language  1772 non-null   object
#  10  Trial Scope                                      1785 non-null   object
#  11  Trial Phase                                      1785 non-null   object
#  12  Age Group                                        1785 non-null   object
#  13  Gender                                           1785 non-null   object
# dtypes: object(14)
# memory usage: 209.2+ KB

# %%
depression_trials.describe().transpose()
# Out:
#                                                 count unique  \
# EudraCT Number:                                  1785    852
# Country                                          1768     31
# Member State                                     1757     28
# Start Date                                       1785   1255
# End Date                                         1042    493
# Trial Status:                                    1707      8
# Therapeutic area                                 1785      4
# Main objective of the trial                      1783   1059
# Medical condition(s) being investigated          1780    750
# Medical condition in easily understood language  1772    701
# Trial Scope                                      1785     23
# Trial Phase                                      1785     10
# Age Group                                        1785     13
# Gender                                           1785      3
#
#                                                                                                top  \
# EudraCT Number:                                                                     2019-002992-33
# Country                                                                              United States
# Member State                                                                       Germany - BfArM
# Start Date                                                                              2012-10-22
# End Date                                                                                2013-09-03
# Trial Status:                                                                            Completed
# Therapeutic area                                 Psychiatry and Psychology [F] - Mental Disorde...
# Main objective of the trial                      Evaluation of the long-term safety and tolerab...
# Medical condition(s) being investigated                                  Major Depressive Disorder
# Medical condition in easily understood language                                      Schizophrenia
# Trial Scope                                                                       Safety, Efficacy
# Trial Phase                                                   Therapeutic confirmatory (Phase III)
# Age Group                                               Adults (18-64 years), Elderly (>=65 years)
# Gender                                                                                Female, Male
#
#                                                  freq
# EudraCT Number:                                    14
# Country                                           375
# Member State                                      182
# Start Date                                          6
# End Date                                           13
# Trial Status:                                    1010
# Therapeutic area                                 1493
# Main objective of the trial                        15
# Medical condition(s) being investigated           181
# Medical condition in easily understood language   160
# Trial Scope                                       691
# Trial Phase                                       969
# Age Group                                         709
# Gender                                           1725

# %%
#neural_trials.info()

# %%
#neural_trials.describe().transpose()

# %%
#depression_trials.to_csv("depression_trials.csv")
#neural_trials.to_csv("neural_trials.csv")

# %%
neurology_trials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11615 entries, 0 to 114313
# Data columns (total 14 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   EudraCT Number:                                  11615 non-null  object
#  1   Country                                          11452 non-null  object
#  2   Member State                                     11431 non-null  object
#  3   Start Date                                       11615 non-null  object
#  4   End Date                                         6243 non-null   object
#  5   Trial Status:                                    11251 non-null  object
#  6   Therapeutic area                                 11615 non-null  object
#  7   Main objective of the trial                      11615 non-null  object
#  8   Medical condition(s) being investigated          11551 non-null  object
#  9   Medical condition in easily understood language  11489 non-null  object
#  10  Trial Scope                                      11615 non-null  object
#  11  Trial Phase                                      11615 non-null  object
#  12  Age Group                                        11615 non-null  object
#  13  Gender                                           11615 non-null  object
# dtypes: object(14)
# memory usage: 1.3+ MB

# %%
neurology_trials.describe().T
# Out:
#                                                  count unique  \
# EudraCT Number:                                  11615   3732
# Country                                          11452     49
# Member State                                     11431     29
# Start Date                                       11615   3389
# End Date                                          6243   1624
# Trial Status:                                    11251     10
# Therapeutic area                                 11615      2
# Main objective of the trial                      11615   5933
# Medical condition(s) being investigated          11551   4455
# Medical condition in easily understood language  11489   4310
# Trial Scope                                      11615     28
# Trial Phase                                      11615     13
# Age Group                                        11615     29
# Gender                                           11615      4
#
#                                                                                                top  \
# EudraCT Number:                                                                     2012-005012-26
# Country                                                                                    Germany
# Member State                                                                         Spain - AEMPS
# Start Date                                                                              2021-06-17
# End Date                                                                                2022-12-31
# Trial Status:                                                                            Completed
# Therapeutic area                                      Diseases [C] - Nervous System Diseases [C10]
# Main objective of the trial                      Demonstrate that ofatumumab 20 mg sc once ever...
# Medical condition(s) being investigated                               Relapsing Multiple Sclerosis
# Medical condition in easily understood language                                           Epilepsy
# Trial Scope                                                              Therapy, Safety, Efficacy
# Trial Phase                                                   Therapeutic confirmatory (Phase III)
# Age Group                                               Adults (18-64 years), Elderly (>=65 years)
# Gender                                                                                Female, Male
#
#                                                   freq
# EudraCT Number:                                     22
# Country                                           2199
# Member State                                      1040
# Start Date                                          40
# End Date                                            31
# Trial Status:                                     6141
# Therapeutic area                                  6612
# Main objective of the trial                         27
# Medical condition(s) being investigated            122
# Medical condition in easily understood language    315
# Trial Scope                                       4886
# Trial Phase                                       6477
# Age Group                                         7887
# Gender                                           11484

# %%
depression_trials.to_csv("depression_trials.csv")
neurology_trials.to_csv("neurology_trials.csv")
